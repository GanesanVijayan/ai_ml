# %%
import numpy as np

u = np.array([3,4])
v = np.array([30,40])

# %%
# length / magnitude of a vector

print(np.linalg.norm(u))
print(np.linalg.norm(v))
# Out:
# 5.0
# 50.0

# %%
def direction(x):
    return x/np.linalg.norm(x)

# %%
w = direction(u)
z = direction(v)
print(w)
print(z)
# Out:
# [0.6 0.8]
# [0.6 0.8]

# %%
# Direction vector always has a unit length i.e. norm / magnitude of the direction vector is always 1 

print(np.linalg.norm(w))
print(np.linalg.norm(z))
# Out:
# 1.0
# 1.0

# %%
# Dot product / projection of one vector on other, influence of one over the other
import math

def geometric_dot_product(x,y, theta):
    x_norm = np.linalg.norm(x)
    y_norm = np.linalg.norm(y)
    return x_norm * y_norm * math.cos(math.radians(theta))

# %%
theta = 45   # reduce theta, dot product will increase
X = [3,5]
y = [8,2]

print(geometric_dot_product(X, y, theta))
# Out:
# 34.00000000000001

# %%
def dot_product(X,y):
    result = 0
    for i in range (len(X)):
        result = result + X[i]*y[i]
    return(result)

# %%
X = [3,5]
y = [8,2]

print(dot_product(X,y))  # should get the same result as geometric dot produt. 
                         # instead of finding the theta, simply multiply the magnitudes of the respective dimensions
# Out:
# 34

# %%
X = np.array([0, 1, 2, 3])
y = np.array([-1, 0.2, 0.9, 2.1])
# print(np.ones(len(X)))
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, y)[0]
# print(m)  # recall m is tan(@) and very close to 1 indicating the theta to be 45 degrees
# Out:
# C:\Users\Ganesan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """

# %%
import matplotlib.pyplot as plt


plt.plot(X, m*X + c, 'b', label='line')
plt.legend()
plt.show()

# %%
# Exercise 1 on equation of a line - given the data, find the slope and intercept and express the equation, draw the line

# %%
import numpy as np

X = np.array([0, 1, 2, 3, 4])
y = np.array([2,4,6,8,10])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, y)[0]
print(m)  # recall m is tan(@) and very close to 1 indicating the theta to be 45 degrees
# Out:
# 2.0
# C:\Users\Ganesan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
import matplotlib.pyplot as plt


plt.plot(X, m*X + c, label='line')
plt.legend()
plt.show()
