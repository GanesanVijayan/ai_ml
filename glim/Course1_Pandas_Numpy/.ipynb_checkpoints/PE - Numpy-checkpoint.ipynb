# %% [markdown]
# # Numpy

# %% [markdown]
# We have seen python basic data structures in our last section. They are great but lack specialized features for data analysis. Like, adding roows, columns, operating on 2d matrices aren't readily available. So, we will use *numpy* for such functions.

# %%
import numpy as np

# %% [markdown]
# Numpy operates on *nd* arrays. These are similar to lists but contains homogenous elements but easier to store 2-d data.

# %%
l1 = [1,2,3,4]
nd1 = np.array(l1)
print(nd1)

l2 = [5,6,7,8]
nd2 = np.array([l1,l2])
print(nd2)
# Out:
# [1 2 3 4]
# [[1 2 3 4]
#  [5 6 7 8]]

# %% [markdown]
# Sum functions on np.array()

# %%
print(nd2.shape)

print(nd2.size)

print(nd2.dtype)
# Out:
# (2, 4)
# 8
# int32

# %% [markdown]
# ### Question 1
#
# Create an identity 2d-array or matrix (with ones across the diagonal).
#
# [ **Hint:** You can also use **np.identity()** function ]

# %%
#l3=np.array([[1,0],[0,1]])
#l3
nd3=np.identity(3)
l3
# Out:
# matrix([[9, 8, 7],
#         [6, 5, 4],
#         [3, 2, 1]])

# %% [markdown]
# ### Question 2
#
# Create a 2d-array or matrix of order 3x3 with values = 9,8,7,6,5,4,3,2,1 arranged in the same order.
#
# Use: **np.matrix()** function

# %%
nd3 = np.matrix([[9,8,7],[6,5,4],[3,2,1]])
nd3
# Out:
# matrix([[9, 8, 7],
#         [6, 5, 4],
#         [3, 2, 1]])

# %% [markdown]
# ### Question 3
#
# Interchange both the rows and columns of the given matrix.
#
# Hint: You can use the transpose **.T**)

# %%
nd3.T
# Out:
# matrix([[9, 6, 3],
#         [8, 5, 2],
#         [7, 4, 1]])

# %% [markdown]
# ### Question 4
# Add + 1 to all the elements in the given matrix.

# %%
nd3+1
# Out:
# matrix([[10,  9,  8],
#         [ 7,  6,  5],
#         [ 4,  3,  2]])

# %%
nd3-1
# Out:
# matrix([[8, 7, 6],
#         [5, 4, 3],
#         [2, 1, 0]])

# %%
nd3*.5
# Out:
# matrix([[4.5, 4. , 3.5],
#         [3. , 2.5, 2. ],
#         [1.5, 1. , 0.5]])

# %%
nd3/.5
# Out:
# matrix([[18., 16., 14.],
#         [12., 10.,  8.],
#         [ 6.,  4.,  2.]])

# %% [markdown]
# Similarly you can do operations like scalar  substraction, division, multiplication (operating on each element in the matrix)

# %% [markdown]
# ### Question 5
#
# Find the mean of all elements in the given matrix nd6.
# nd6 = [[  1   4   9 121 144 169]
#  [ 16  25  36 196 225 256]
#  [ 49  64  81 289 324 361]]
#
#  Use: **.mean()** function

# %%
nd6 = [[ 1, 4, 9, 121, 144, 169], [ 16, 25, 36, 196, 225, 256], [ 49, 64, 81, 289, 324, 361]]

l4 = np.matrix(nd6)
l4.mean()
#l4.std()
# Out:
# 131.66666666666666

# %% [markdown]
# ### Question 7
#
# Find the dot product of two given matrices.
#
# [**Hint:** Use **np.dot()**]

# %%
nd7=np.random.rand(3,3)
nd7
# Out:
# array([[0.07324339, 0.17723043, 0.78202854],
#        [0.15311099, 0.79481968, 0.87822352],
#        [0.05466971, 0.52795389, 0.89280122]])

# %%
nd8=np.random.randn(3,4)
nd8
# Out:
# array([[-0.54645431,  2.1459871 ,  0.36061193, -0.66298183],
#        [-0.105252  ,  0.90190059, -1.06057104, -0.53502475],
#        [ 0.09102421, -0.4487132 ,  0.74891864,  0.80774464]])

# %%
np.dot(nd7,nd8)
# Out:
# array([[ 0.0125055 , -0.03388293,  0.42412273,  0.48829766],
#        [-0.08738492,  0.65135206, -0.13003112,  0.18262234],
#        [-0.00417618,  0.19287073,  0.12841742,  0.40244198]])
