# %%
import pandas as pd

X= [ 4, 5, 8, 10, 11]
y=  [50, 48, 45 , 42, 41]
df = pd.DataFrame(data=[X,y]).transpose()

# %%
df.head()
# Out:
#     0   1
# 0   4  50
# 1   5  48
# 2   8  45
# 3  10  42
# 4  11  41

# %%
df.corr()
# Out:
#           0         1
# 0  1.000000 -0.996382
# 1 -0.996382  1.000000
