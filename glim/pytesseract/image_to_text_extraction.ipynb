# %%
# pip install pytesseract

# %%
# pip list

# %%
import pytesseract

# %%
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\OCR\\tesseract-ocr-w64-setup-v5.0.0-alpha.20201127.exe'

# %%
img = Image.open('image_to_text_extraction.png')

# %%
text_extract = pytesseract.image_to_string(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-c1ce6b6c7e00> in <module>
# ----> 1 text_extract = pytesseract.image_to_string(img)
#
# ~\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     372         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     373         Output.STRING: lambda: run_and_get_output(*args),
# --> 374     }[output_type]()
#     375
#     376
#
# ~\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     371         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     372         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 373         Output.STRING: lambda: run_and_get_output(*args),
#     374     }[output_type]()
#     375
#
# ...
